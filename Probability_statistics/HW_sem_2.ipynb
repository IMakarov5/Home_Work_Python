# %% [markdown]
# # Теория вероятностей и математическая статистика (семинары)
# # Урок 2. Дискретные распределения вероятностей

# %% [markdown]
# Условие:
#
# ## 1. Вероятность того, что стрелок попадет в мишень, выстрелив один раз, равна 0.8. Стрелок выстрелил 100 раз. Найдите вероятность того, что стрелок попадет в цель ровно 85 раз.

# %% [markdown]
# Cлучайная дискретная величина Х имеет биномиальное распределение с переменными k,n и p, если вероятность ее распределения задается следующим уравнением:
#
# P(X=k) = C(n,k)*p^k*q^(n-k)
#
# ✔	k ,число наступления события (дискретная величина из отрезка [0, n])
# ✔	n -  число испытаний
# ✔	p - вероятность наступления события A в  независимых испытаниях,
# ✔	q = 1 – p. Противоположная вероятность
#
# Выше приведенная формула для вычисления вероятностей наступления события k раз из n и есть формула Бернулли.

# %%
from math import factorial

def C (n: int, k: int) -> float:
    # Сочетание
    
    return (factorial(n) / (factorial(k) * factorial(n - k))) 

def A (n: int, k: int) -> float:
    # Размещение
    
    return (factorial(n) / factorial(n - k)) 

def Pn (n: int, ) -> float:
    # Перестановка
    
    return factorial(n)



def Pn (k: int, n: int, p: float) -> float:
    # формула Бернулли P(X=k) = C(n,k)*p^k*q^(n-k)
    P = C(n,k) * p**k * (1-p)**(n-k)
     
    return P


def Pm (m: int, Lam: float) -> float:
    #  Распределение Пуассона Pm≈λ^m/m!*e^-λ
    e = 2.72
    P =(Lam**m/ (factorial(m)))*e**(-Lam)

    return P

# %%
k=85
n=100
p=0.8

print('Вероятность того, что стрелок попадет в цель ровно 85 раз: ', Pn(k,n,p))
# Out:
# Вероятность того, что стрелок попадет в цель ровно 85 раз:  0.048061793700746355

# %% [markdown]
# ## 2. Вероятность того, что лампочка перегорит в течение первого дня эксплуатации, равна 0.0004. В жилом комплексе после ремонта в один день включили 5000 новых лампочек.
#
# ### Какова вероятность, что ни одна из них не перегорит в первый день?
# ### Какова вероятность, что перегорят ровно две?

# %% [markdown]
# Распределение Пуассона
#
# В том случае, если вероятность наступления события очень маленькая  (< 0.1), а число испытаний очень большое, применяется формула Пуассона. Распределение Пуассона это также дискретное распределение и является частным случаем биномиального распределения.
#
#
# Pm≈λ^m/m!*e^-λ

# %%
p = 0.0004

Lam = p * 5000

m = 0

print('Вероятность, что ни одна из них не перегорит в первый день: ', Pm(m,Lam))

m = 2

print('Какова вероятность, что перегорят ровно две: ', Pm(m,Lam))
# Out:
# Вероятность, что ни одна из них не перегорит в первый день:  0.13516435986159167
# Какова вероятность, что перегорят ровно две:  0.27032871972318334

# %% [markdown]
# ## 3. Монету подбросили 144 раза. Какова вероятность, что орел выпадет ровно 70 раз?

# %%
k=70
n=144
p=0.5

print('Вероятность, что орел выпадет ровно 70 раз: ', Pn(k,n,p))
# Out:
# Вероятность, что орел выпадет ровно 70 раз:  0.06281178035144776

# %% [markdown]
# ## 4. В первом ящике находится 10 мячей, из которых 7 - белые. Во втором ящике - 11 мячей, из которых 9 белых. Из каждого ящика вытаскивают случайным образом по два мяча.
# ### Какова вероятность того, что все мячи белые?
# ### Какова вероятность того, что ровно два мяча белые?
# ### Какова вероятность того, что хотя бы один мяч белый?

# %%
m1 = C (7,2) 
n1 = C (10,2)
P1=m1/n1
print (P1) 



m2 = C (9,2) 
n2 = C (11,2)
P2=m2/n2

print (P2) 
p=P1+P2
print('Вероятность того, что все мячи белые: ', p)

###########################################



m1 = C (7,2) 
P1=m1/n1
print (P1) 

m2 = C (9,2)
P2=m2/n2

print (P2) 
p=P1*P2

print('Вероятность того, что ровно два мяча белые: ',p)



###########################################
m1 = C (7,1) 

P1=m1/n1
print (P1) 

m2 = C (9,1) 

P2=m2/n2



print (P2) 
p=P1+P2
print('Вероятность того, что хотя бы один мяч белый:', p)
# Out:
# 0.4666666666666667
# 0.6545454545454545
# Вероятность того, что все мячи белые:  1.121212121212121
# 0.4666666666666667
# 0.6545454545454545
# Вероятность того, что ровно два мяча белые:  0.3054545454545455
# 0.15555555555555556
# 0.16363636363636364
# Вероятность того, что хотя бы один мяч белый: 0.3191919191919192

# %%
m3 = C (16,4)
n3 = C (21,4)
print(m3,' ',n3)
P3=m3/n3
print (P3) 


print('Вероятность того, что все мячи белые: ', P3)

###########################################



m3 = C (16,2) 
print(m3,' ',n3)
n3 = C (21,4)
P3=m3/n3
print (P3) 


print('Вероятность того, что ровно два мяча белые: ',P3)



###########################################
m3 = C (16,1) 
n3 = C (21,4)
print(m3,' ',n3)
P3=m3/n3
print (P3) 

print('Вероятность того, что хотя бы один мяч белый:', P3)
# Out:
# 1820.0   5985.0
# 0.30409356725146197
# Вероятность того, что все мячи белые:  0.30409356725146197
# 120.0   5985.0
# 0.020050125313283207
# Вероятность того, что ровно два мяча белые:  0.020050125313283207
# 16.0   5985.0
# 0.0026733500417710945
# Вероятность того, что хотя бы один мяч белый: 0.0026733500417710945
